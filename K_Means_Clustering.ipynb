# %% [markdown]
# <a href="https://colab.research.google.com/github/Vibhu-Maurya/Machine-Learning-project/blob/main/K_Means_Clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
X = np.array([
    [1,2],[1.5,1.8],[5,8],[5,5],[1,0.6],[9,11],[8,2],[10,2],[9,3]
])

# %%
kmeans = KMeans(n_clusters=2, random_state=0)

# %%
kmeans.fit(X)
# Out:
# KMeans(n_clusters=2, random_state=0)

# %%
centers=kmeans.cluster_centers_
labels=kmeans.labels_

# %%
#step 6
colors = ["red","green","blue"]

# %%
for i in range(len(X)):
  plt.scatter(X[i][0],X[i][1],color=colors[kmeans.labels_[i]])

# %%
plt.scatter(centroids[:,0],centroids[:,1],marker='X',s=200, color)
# Out:
#   File "/tmp/ipython-input-826181128.py", line 1
#     plt.scatter(centroids[:,0],centroids[:,1],marker='X',s=200, color)
#                                                                      ^
# SyntaxError: positional argument follows keyword argument

# %% [markdown]
# ## Hieerarchical cl

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram,linkage,fcluster

# %%
X = np.array([
    [1,4],[6,7],[9,5],[93,5],[2,3],[3,4]
])

# %%
z = linkage(X, method='ward')

# %%
plt.figure(figsize=(8,5))
dendrogram(z)
plt.xlabel('data points')
plt.ylabel('Distance')
plt.title('Dendogram')
plt.show()

# %%
clusters =fcluster(z,t=5,criterion='maxclust')
print("clusterlabels",clusters)
# Out:
# clusterlabels [1 3 4 5 1 2]
